# %%
pip install opencv-python

# %%
from google.colab.patches import cv2_imshow
import cv2
rasm=cv2.imread("images.jfif")
cv2_imshow(rasm)
# Out:
# <PIL.Image.Image image mode=RGB size=284x177>

# %%
oqqora=cv2.cvtColor(rasm,cv2.COLOR_BGR2GRAY)
cv2_imshow(oqqora)
# Out:
# <PIL.Image.Image image mode=L size=284x177>

# %%
from google.colab.patches import cv2_imshow
import cv2
rasm=cv2.imread("images (2).jfif")
cv2_imshow(rasm)
# Out:
# <PIL.Image.Image image mode=RGB size=199x253>

# %%
oqqora=cv2.cvtColor(rasm,cv2.COLOR_BGR2GRAY)
cv2_imshow(oqqora)
# Out:
# <PIL.Image.Image image mode=L size=199x253>

# %%
from google.colab.patches import cv2_imshow
import cv2
rasm=cv2.imread("images (3).jfif")
cv2_imshow(rasm)
# Out:
# <PIL.Image.Image image mode=RGB size=268x188>

# %%
oqqora=cv2.cvtColor(rasm,cv2.COLOR_BGR2GRAY)
cv2_imshow(oqqora)
# Out:
# <PIL.Image.Image image mode=L size=268x188>

# %%
from google.colab.patches import cv2_imshow
import cv2
rasm=cv2.imread("images (4).jfif")
cv2_imshow(rasm)
# Out:
# <PIL.Image.Image image mode=RGB size=192x263>

# %%
oqqora=cv2.cvtColor(rasm,cv2.COLOR_BGR2GRAY)
cv2_imshow(oqqora)
# Out:
# <PIL.Image.Image image mode=L size=192x263>

# %%
from google.colab.patches import cv2_imshow
import cv2
rasm=cv2.imread("images (5).jfif")
cv2_imshow(rasm)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194>

# %%
oqqora=cv2.cvtColor(rasm,cv2.COLOR_BGR2GRAY)
cv2_imshow(oqqora)
# Out:
# <PIL.Image.Image image mode=L size=259x194>
